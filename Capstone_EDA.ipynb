# %% [markdown]
# # Code for Cleaning, Manipulating, and Predicting Car Sales

# %% [markdown]
# ### Data Acquisition

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

train_full = pd.read_csv('train.csv')  	
train_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
#  16  Color             19237 non-null  object
#  17  Airbags           19237 non-null  int64
# dtypes: float64(1), int64(4), object(13)
# memory usage: 2.6+ MB

# %% [markdown]
# ### Initial Data Inspection

# %%
print(train_full.head(n=10))
print(train_full.describe())
# Out:
#          ID  Price  Levy Manufacturer     Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS    RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET   Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA       FIT        2006  Hatchback
# 3  45769185   3607   862         FORD    Escape        2011       Jeep
# 4  45809263  11726   446        HONDA       FIT        2014  Hatchback
# 5  45802912  39493   891      HYUNDAI  Santa FE        2016       Jeep
# 6  45656768   1803   761       TOYOTA     Prius        2010  Hatchback
# 7  45816158    549   751      HYUNDAI    Sonata        2013      Sedan
# 8  45641395   1098   394       TOYOTA     Camry        2014      Sedan
# 9  45756839  26657     -        LEXUS    RX 350        2007       Jeep
#
#   Leather interior Fuel type Engine volume  Mileage  Cylinders Gear box type  \
# 0              Yes    Hybrid           3.5   186005        6.0     Automatic
# 1               No    Petrol             3   192000        6.0     Tiptronic
# 2               No    Petrol           1.3   200000        4.0      Variator
# 3              Yes    Hybrid           2.5   168966        4.0     Automatic
# 4              Yes    Petrol           1.3    91901        4.0     Automatic
# 5              Yes    Diesel             2   160931        4.0     Automatic
# 6              Yes    Hybrid           1.8   258909        4.0     Automatic
# 7              Yes    Petrol           2.4   216118        4.0     Automatic
# 8              Yes    Hybrid           2.5   398069        4.0     Automatic
# 9              Yes    Petrol           3.5   128500        6.0     Automatic
#
#   Drive wheels   Doors             Wheel   Color  Airbags
# 0          4x4  04-May        Left wheel  Silver       12
# 1          4x4  04-May        Left wheel   Black        8
# 2        Front  04-May  Right-hand drive   Black        2
# 3          4x4  04-May        Left wheel   White        0
# 4        Front  04-May        Left wheel  Silver        4
# 5        Front  04-May        Left wheel   White        4
# 6        Front  04-May        Left wheel   White       12
# 7        Front  04-May        Left wheel    Grey       12
# 8        Front  04-May        Left wheel   Black       12
# 9          4x4  04-May        Left wheel  Silver       12
#                  ID         Price    Prod. year       Mileage     Cylinders  \
# count  1.923700e+04  1.923700e+04  19237.000000  1.923700e+04  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824  1.532236e+06      4.582991
# std    9.365914e+05  1.905813e+05      5.668673  4.840387e+07      1.199933
# min    2.074688e+07  1.000000e+00   1939.000000  0.000000e+00      1.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000  7.013900e+04      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000  1.260000e+05      4.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000  1.888880e+05      4.000000
# max    4.581665e+07  2.630750e+07   2020.000000  2.147484e+09     16.000000
#
#             Airbags
# count  19237.000000
# mean       6.582627
# std        4.320168
# min        0.000000
# 25%        4.000000
# 50%        6.000000
# 75%       12.000000
# max       16.000000

# %% [markdown]
# ### Initial Descriptive Statistics

# %%
train_full.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %% [markdown]
# ### Range of Years

# %%
min_year = train_full['Prod. year'].min()
max_year = train_full['Prod. year'].max()
print(f"Range of years: {min_year} to {max_year}")
plt.figure(figsize=(10, 6))
plt.hist(train_full['Prod. year'], bins=range(train_full['Prod. year'].min(), train_full['Prod. year'].max() + 1), color='green', edgecolor='black')
plt.title('Distribution of Cars by Year')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# Range of years: 1939 to 2020

# %% [markdown]
# ### Fuel Type Distribution

# %%
fuel_type_counts = train_full['Fuel type'].value_counts()

plt.pie(fuel_type_counts, labels=fuel_type_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Distribution of Cars Based on Fuel Type')
plt.legend(fuel_type_counts, loc='upper right')
plt.show()

# %% [markdown]
# ### Average Price of Car by Year

# %%
mean_prices = train_full.groupby('Prod. year')['Price'].mean().reset_index()

plt.figure(figsize=(10, 6))
plt.scatter(mean_prices['Prod. year'], mean_prices['Price'], color='black', alpha=0.7)
plt.title("Mean Car Prices by Year")
plt.xlabel("Year")
plt.ylabel("Mean Price in USD")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Convert String to Float of Mileage

# %%
train_full['Mileage'] = train_full['Mileage'].astype(str).str.replace(r'\D', '', regex=True)
train_full['Mileage'] = pd.to_numeric(train_full['Mileage'], errors='coerce').fillna(0).astype(int)

# %% [markdown]
# ### Relationship Between Selling Price and Mileage with Gear Box Type

# %%
train_full['Mileage'].max()
# Out:
# np.int64(2147483647)

# %%
price_mileage_corr = train_full['Price'].corr(train_full['Mileage'])
print("Correlation between Selling Price and Mileage:", price_mileage_corr)

plt.figure(figsize=(10, 6))
sns.scatterplot(x="Mileage", y="Price", data=train_full, hue="Gear box type", palette="viridis")
plt.title("Relationship between Selling Price and Mileage with Gear Box Type")
plt.xlim(0, 900000)
plt.ylim(0, 150000)
plt.xlabel("Driven Kilometers")
plt.ylabel("Selling Price (in USD)")
plt.legend(title="Fuel Type")
plt.grid(True)
plt.show()
# Out:
# Correlation between Selling Price and Mileage: -0.0017583793718207335

# %% [markdown]
# ### Relationship between Number of Cylinders and Price

# %%
cylinder_price_corr = train_full['Price'].corr(train_full['Cylinders'])
filtered_data = train_full[(train_full['Price'] >= 1000) & (train_full['Price'] <= 200000)]

print("Correlation between Selling Price and years:", cylinder_price_corr)
plt.scatter(filtered_data['Cylinders'], filtered_data['Price'], alpha=0.7)
plt.title('Selling Price vs Cylinders')
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: f"{int(x):,}"))
plt.xlabel('Cylinders')
plt.ylabel('Selling Price')
plt.grid(True)
plt.show()
# Out:
# Correlation between Selling Price and years: 0.00751802258755772

# %% [markdown]
# ### Top 15 Models Sold

# %%
model_counts = train_full['Model'].value_counts()
top_15_models = model_counts.head(15)

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_15_models, labels=top_15_models.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 15 Models Distribution')
plt.axis('equal')  
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 10 Manufactures

# %%
manufacturer_counts = train_full['Manufacturer'].value_counts()
top_10_manufacturer = manufacturer_counts.head(10)

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_10_manufacturer, labels=top_10_manufacturer.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 10 Manufacturer Distribution')
plt.axis('equal')  
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Removing Unnecessary Columns before Machine Learning Algorithms

# %%
train_full.drop(['Leather interior', 'Drive wheels', 'Doors', 'Wheel', 'Color', 'Airbags', 'Levy'], axis=1, inplace=True)

# %%
train_full.head(10)
# Out:
#          ID  Price Manufacturer     Model  Prod. year   Category Fuel type  \
# 0  45654403  13328        LEXUS    RX 450        2010       Jeep    Hybrid
# 1  44731507  16621    CHEVROLET   Equinox        2011       Jeep    Petrol
# 2  45774419   8467        HONDA       FIT        2006  Hatchback    Petrol
# 3  45769185   3607         FORD    Escape        2011       Jeep    Hybrid
# 4  45809263  11726        HONDA       FIT        2014  Hatchback    Petrol
# 5  45802912  39493      HYUNDAI  Santa FE        2016       Jeep    Diesel
# 6  45656768   1803       TOYOTA     Prius        2010  Hatchback    Hybrid
# 7  45816158    549      HYUNDAI    Sonata        2013      Sedan    Petrol
# 8  45641395   1098       TOYOTA     Camry        2014      Sedan    Hybrid
# 9  45756839  26657        LEXUS    RX 350        2007       Jeep    Petrol
#
#   Engine volume  Mileage  Cylinders Gear box type
# 0           3.5   186005        6.0     Automatic
# 1             3   192000        6.0     Tiptronic
# 2           1.3   200000        4.0      Variator
# 3           2.5   168966        4.0     Automatic
# 4           1.3    91901        4.0     Automatic
# 5             2   160931        4.0     Automatic
# 6           1.8   258909        4.0     Automatic
# 7           2.4   216118        4.0     Automatic
# 8           2.5   398069        4.0     Automatic
# 9           3.5   128500        6.0     Automatic

# %%
train_full.to_csv('cleaned_data.csv', index=False)
